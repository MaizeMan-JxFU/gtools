# %%
import pandas as pd
fam = pd.read_csv('mouse_hs1940.fam.bkup',sep='\t',index_col=0,header=None)
p = pd.read_csv('mouse_hs1940.pheno.txt',sep='\t',index_col=None,header=None)
p.columns = 'test'+p.columns.astype(str)
p.index = range(len(p))
fam.index = range(len(p))
p.fillna('NA').to_csv('mouse_hs1940.pheno',sep='\t',index=True)
fam.fillna('NA').to_csv('mouse_hs1940.fam',sep='\t',index=True,header=False)
